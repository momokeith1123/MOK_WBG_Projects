# %%
# Cell 1 - Imports
import requests
import pandas as pd
import time

# %%
# Cell 2 — Configuration (only this cell needs to be updated)
BASE_URL = "https://findata-qa.worldbank.org:9047"
TOKEN    = "3/Cw8MfRR5CgJxP9cfVlot3cd95gGBfZvwEa7jp3tBOU9UWfFCJ8e6k6KAhF0w=="
SCHEMA   = ["publishFINDATAREP", "IFCTRE", "Application", "Murex"]

HEADERS = {
    "Authorization": f"Bearer {TOKEN}",
    "Content-Type": "application/json"
}

# ── All your queries ──
QUERIES = {
    "perf_attribution"      : 'SELECT * FROM "Perf_Attribution"',
    "perf_benchmark"        : 'SELECT * FROM "Perf_Benchmark_Weights"',
    "perf_vs_funding"       : 'SELECT * FROM "Perf_Vs_Funding_Snap"',
    "plvar_snapshot"        : 'SELECT * FROM "Plvar_Snapshot"',
    "portfolio_details"     : 'SELECT * FROM "Portfolio_Details"',
    "securities_detail"     : 'SELECT * FROM "Securities_Detail"',
    "trade_mktval_detail"   : 'SELECT * FROM "Trade_Mktval_Detail"',
    "security_prices_detail": 'SELECT * FROM "Security_Prices_Detail"',
    "inv_pnl_summary"       : 'SELECT * FROM "Inv_Pnl_Summary"',
    "inv_security_position" : 'SELECT * FROM "Inv_Security_Position"',  # ← new
}

# ── Only change this line to switch query ──
SQL_QUERY = QUERIES[ "inv_pnl_summary" ]

# %%
# Cell 3 — Display function
def display_df(df):
    return df.style.set_properties(**{
        'white-space': 'nowrap',
        'font-size': '11px',
        'text-align': 'left',
        'border': '1px solid lightgrey',
        'color': 'black'
    }).set_table_styles([
        {
            'selector': 'thead th',
            'props': [
                ('white-space', 'nowrap'),
                ('font-size', '11px'),
                ('font-weight', 'bold'),
                ('background-color', '#4472C4'),
                ('color', 'white'),
                ('text-align', 'center'),
                ('border', '1px solid lightgrey')
            ]
        },
        {
            'selector': 'tbody tr:nth-child(even)',
            'props': [('background-color', '#f2f2f2'), ('color', 'black')]
        },
        {
            'selector': 'tbody tr:nth-child(odd)',
            'props': [('background-color', 'white'), ('color', 'black')]
        },
        {
            'selector': 'tbody tr:hover',
            'props': [('background-color', '#d6e4f0'), ('color', 'black')]
        }
    ])

# %%
# Cell 4 — Submit the SQL job
response = requests.post(
    f"{BASE_URL}/api/v3/sql",
    headers=HEADERS,
    json={
        "sql": SQL_QUERY,
        "context": SCHEMA
    },
    verify=True,
    timeout=30
)
response.raise_for_status()
job_id = response.json().get("id")
print(f"Job submitted successfully.")
print(f"Job ID: {job_id}")
# Out:
# Job submitted successfully.
# Job ID: 159c8cc3-3534-7019-8450-68fc33a97e00

# %%
# Cell 5 — Poll until job completes
url = f"{BASE_URL}/api/v3/job/{job_id}"
for attempt in range(30):
    response = requests.get(url, headers=HEADERS, verify=True)
    response.raise_for_status()
    status = response.json().get("jobState")
    print(f"Attempt {attempt + 1}: {status}")
    if status == "COMPLETED":
        print("Job completed!")
        break
    elif status in ("FAILED", "CANCELED"):
        print(f"Job failed: {response.json().get('errorMessage')}")
        break
    time.sleep(2)
# Out:
# Attempt 1: COMPLETED
# Job completed!

# %%
# Cell 6 — Fetch results and build DataFrame
response = requests.get(
    f"{BASE_URL}/api/v3/job/{job_id}/results?offset=0&limit=500",
    headers=HEADERS,
    verify=True
)
response.raise_for_status()
data = response.json()

columns   = [col["name"] for col in data.get("schema", [])]
all_rows  = data.get("rows", [])
total     = data.get("rowCount", None)

# ── Paginate if more than 500 rows ──
offset = 500
while True:
    r = requests.get(
        f"{BASE_URL}/api/v3/job/{job_id}/results?offset={offset}&limit=500",
        headers=HEADERS,
        verify=True
    )
    batch = r.json().get("rows", [])
    if not batch:
        break
    all_rows.extend(batch)
    offset += len(batch)
    print(f"Fetched {offset} rows so far...")

df = pd.DataFrame(all_rows, columns=columns)
print(f"Total Rows    : {len(df)}")
print(f"Total Columns : {len(df.columns)}")
# Out:
# Fetched 1000 rows so far...
# Fetched 1500 rows so far...
# Fetched 2000 rows so far...
# Fetched 2500 rows so far...
# Fetched 3000 rows so far...
# Fetched 3500 rows so far...
# Fetched 4000 rows so far...
# Fetched 4500 rows so far...
# Fetched 5000 rows so far...
# Fetched 5500 rows so far...
# Fetched 6000 rows so far...
# Fetched 6500 rows so far...
# Fetched 7000 rows so far...
# Fetched 7500 rows so far...
# Fetched 8000 rows so far...
# Fetched 8500 rows so far...
# Fetched 9000 rows so far...
# Fetched 9500 rows so far...
# Fetched 10000 rows so far...
# Fetched 10500 rows so far...
# Fetched 11000 rows so far...
# Fetched 11500 rows so far...
# Fetched 12000 rows so far...
# Fetched 12221 rows so far...
# Total Rows    : 12221
# Total Columns : 41

# %%
display_df(df.head(10))   # first 10 rows
# Out:
# <style type="text/css">
# #T_50313 thead th {
#   white-space: nowrap;
#   font-size: 11px;
#   font-weight: bold;
#   background-color: #4472C4;
#   color: white;
#   text-align: center;
#   border: 1px solid lightgrey;
# }
# #T_50313 tbody tr:nth-child(even) {
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_50313 tbody tr:nth-child(odd) {
#   background-color: white;
#   color: black;
# }
# #T_50313 tbody tr:hover {
#   background-color: #d6e4f0;
#   color: black;
# }
# #T_50313_row0_col0, #T_50313_row0_col1, #T_50313_row0_col2, #T_50313_row0_col3, #T_50313_row0_col4, #T_50313_row0_col5, #T_50313_row0_col6, #T_50313_row0_col7, #T_50313_row0_col8, #T_50313_row0_col9, #T_50313_row0_col10, #T_50313_row0_col11, #T_50313_row0_col12, #T_50313_row0_col13, #T_50313_row0_col14, #T_50313_row0_col15, #T_50313_row0_col16, #T_50313_row0_col17, #T_50313_row0_col18, #T_50313_row0_col19, #T_50313_row0_col20, #T_50313_row0_col21, #T_50313_row0_col22, #T_50313_row0_col23, #T_50313_row0_col24, #T_50313_row0_col25, #T_50313_row0_col26, #T_50313_row0_col27, #T_50313_row0_col28, #T_50313_row0_col29, #T_50313_row0_col30, #T_50313_row0_col31, #T_50313_row0_col32, #T_50313_row0_col33, #T_50313_row0_col34, #T_50313_row0_col35, #T_50313_row0_col36, #T_50313_row0_col37, #T_50313_row0_col38, #T_50313_row0_col39, #T_50313_row0_col40, #T_50313_row1_col0, #T_50313_row1_col1, #T_50313_row1_col2, #T_50313_row1_col3, #T_50313_row1_col4, #T_50313_row1_col5, #T_50313_row1_col6, #T_50313_row
# %%
display_df(df.tail(10))   # last 10 rows
# Out:
# <style type="text/css">
# #T_996c2 thead th {
#   white-space: nowrap;
#   font-size: 11px;
#   font-weight: bold;
#   background-color: #4472C4;
#   color: white;
#   text-align: center;
#   border: 1px solid lightgrey;
# }
# #T_996c2 tbody tr:nth-child(even) {
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_996c2 tbody tr:nth-child(odd) {
#   background-color: white;
#   color: black;
# }
# #T_996c2 tbody tr:hover {
#   background-color: #d6e4f0;
#   color: black;
# }
# #T_996c2_row0_col0, #T_996c2_row0_col1, #T_996c2_row0_col2, #T_996c2_row0_col3, #T_996c2_row0_col4, #T_996c2_row0_col5, #T_996c2_row0_col6, #T_996c2_row0_col7, #T_996c2_row0_col8, #T_996c2_row0_col9, #T_996c2_row0_col10, #T_996c2_row0_col11, #T_996c2_row0_col12, #T_996c2_row0_col13, #T_996c2_row0_col14, #T_996c2_row0_col15, #T_996c2_row0_col16, #T_996c2_row0_col17, #T_996c2_row0_col18, #T_996c2_row0_col19, #T_996c2_row0_col20, #T_996c2_row0_col21, #T_996c2_row0_col22, #T_996c2_row0_col23, #T_996c2_row0_col24, #T_996c2_row0_col25, #T_996c2_row0_col26, #T_996c2_row0_col27, #T_996c2_row0_col28, #T_996c2_row0_col29, #T_996c2_row0_col30, #T_996c2_row0_col31, #T_996c2_row0_col32, #T_996c2_row0_col33, #T_996c2_row0_col34, #T_996c2_row0_col35, #T_996c2_row0_col36, #T_996c2_row0_col37, #T_996c2_row0_col38, #T_996c2_row0_col39, #T_996c2_row0_col40, #T_996c2_row1_col0, #T_996c2_row1_col1, #T_996c2_row1_col2, #T_996c2_row1_col3, #T_996c2_row1_col4, #T_996c2_row1_col5, #T_996c2_row1_col6, #T_996c2_row1_col7, #T_996c2_row1_col8, #T_996c2_row1_col9, #T_996c2_row1_col10, #T_996c2_row1_col11, #T_996c2_row1_col12, #T_996c2_row1_col13, #T_996c2_row1_col14, #T_996c2_row1_col15, #T_996c2_row1_col16, #T_996c2_row1_col17, #T_996c2_row1_col18, #T_996c2_row1_col19, #T_996c2_row1_col20, #T_996c2_row1_col21, #T_996c2_row1_col22, #T_996c2_row1_col23, #T_996c2_row1_col24, #T_996c2_row1_col25, #T_996c2_row1_col26, #T_996c2_row1_col27, #T_996c2_row1_col28, #T_996c2_row1_col29, #T_996c2_row1_col30, #T_996c2_row1_col31, #T_996c2_row1_col32, #T_996c2_row1_col33, #T_996c2_row1_col34, #T_996c2_row1_col35, #T_996c2_row1_col36, #T_996c2_row1_col37, #T_996c2_row1_col38, #T_996c2_row1_col39, #T_996c2_row1_col40, #T_996c2_row2_col0, #T_996c2_row2_col1, #T_996c2_row2_col2, #T_996c2_row2_col3, #T_996c2_row2_col4, #T_996c2_row2_col5, #T_996c2_row2_col6, #T_996c2_row2_col7, #T_996c2_row2_col8, #T_996c2_row2_col9, #T_996c2_row2_col10, #T_996c2_row2_col11, #T_996c2_row2_col12, #T_996c2_row2_col13, #T_996c2_row2_col14, #T_996c2_row2_col15, #T_996c2_row2_col16, #T_996c2_row2_col17, #T_996c2_row2_col18, #T_996c2_row2_col19, #T_996c2_row2_col20, #T_996c2_row2_col21, #T_996c2_row2_col22, #T_996c2_row2_col23, #T_996c2_row2_col24, #T_996c2_row2_col25, #T_996c2_row2_col26, #T_996c2_row2_col27, #T_996c2_row2_col28, #T_996c2_row2_col29, #T_996c2_row2_col30, #T_996c2_row2_col31, #T_996c2_row2_col32, #T_996c2_row2_col33, #T_996c2_row2_col34, #T_996c2_row2_col35, #T_996c2_row2_col36, #T_996c2_row2_col37, #T_996c2_row2_col38, #T_996c2_row2_col39, #T_996c2_row2_col40, #T_996c2_row3_col0, #T_996c2_row3_col1, #T_996c2_row3_col2, #T_996c2_row3_col3, #T_996c2_row3_col4, #T_996c2_row3_col5, #T_996c2_row3_col6, #T_996c2_row3_col7, #T_996c2_row3_col8, #T_996c2_row3_col9, #T_996c2_row3_col10, #T_996c2_row3_col11, #T_996c2_row3_col12, #T_996c2_row3_col13, #T_996c2_row3_col14, #T_996c2_row3_col15, #T_996c2_row3_col16, #T_996c2_row3_col17, #T_996c2_row3_col18, #T_996c2_row3_col19, #T_996c2_row3_col20, #T_996c2_row3_col21, #T_996c2_row3_col22, #T_996c2_row3_col23, #T_996c2_row3_col24, #T_996c2_row3_col25, #T_996c2_row3_col26, #T_996c2_row3_col27, #T_996c2_row3_col28, #T_996c2_row3_col29, #T_996c2_row3_col30, #T_996c2_row3_col31, #T_996c2_row3_col32, #T_996c2_row3_col33, #T_996c2_row3_col34, #T_996c2_row3_col35, #T_996c2_row3_col36, #T_996c2_row3_col37, #T_996c2_row3_col38, #T_996c2_row3_col39, #T_996c2_row3_col40, #T_996c2_row4_col0, #T_996c2_row4_col1, #T_996c2_row4_col2, #T_996c2_row4_col3, #T_996c2_row4_col4, #T_996c2_row4_col5, #T_996c2_row4_col6, #T_996c2_row4_col7, #T_996c2_row4_col8, #T_996c2_row4_col9, #T_996c2_row4_col10, #T_996c2_row4_col11, #T_996c2_row4_col12, #T_996c2_row4_col13, #T_996c2_row4_col14, #T_996c2_row4_col15, #T_996c2_row4_col16, #T_996c2_row4_col17, #T_996c2_row4_col18, #T_996c2_row4_col19, #T_996c2_row4_col20, #T_996c2_row4_col21, #T_996c2_row4_col22, #T_996c2_row4_col23, #T_996c2_row4_col24, #T_996c2_row4_col25, #T_996c2_row4_col26, #T_996c2_row4_col27, #T_996c2_row4_col2 ...

# %%
# Cell 7 — Display the DataFrame
#display_df(df.head(10))   # first 10 rows
#display_df(df.tail(10))   # last 10 rows
display_df(df)            # everything

# %%
df.tail()

# %%
# Cell 8 — Optional: Save to CSV or Excel
df.to_csv("output.csv", index=False)
print("Saved to output.csv")

df.to_excel("output.xlsx", index=False)
print("Saved to output.xlsx")
