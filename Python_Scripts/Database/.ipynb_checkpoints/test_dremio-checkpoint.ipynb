# %%
# Cell 1 - Imports
import requests
import pandas as pd
import time

# %%
# Cell 2 — Configuration (only this cell needs to be updated)
BASE_URL = "https://findata-qa.worldbank.org:9047"
TOKEN    = "3/Cw8MfRR5CgJxP9cfVlot3cd95gGBfZvwEa7jp3tBOU9UWfFCJ8e6k6KAhF0w=="
SCHEMA   = ["publishFINDATAREP", "IFCTRE", "Application", "Murex"]

HEADERS = {
    "Authorization": f"Bearer {TOKEN}",
    "Content-Type": "application/json"
}

# ── All your queries ──
QUERIES = {
    "perf_attribution"      : 'SELECT * FROM "Perf_Attribution"',
    "perf_benchmark"        : 'SELECT * FROM "Perf_Benchmark_Weights"',
    "perf_vs_funding"       : 'SELECT * FROM "Perf_Vs_Funding_Snap"',
    "plvar_snapshot"        : 'SELECT * FROM "Plvar_Snapshot"',
    "portfolio_details"     : 'SELECT * FROM "Portfolio_Details"',
    "securities_detail"     : 'SELECT * FROM "Securities_Detail"',
    "trade_mktval_detail"   : 'SELECT * FROM "Trade_Mktval_Detail"',
    "security_prices_detail": 'SELECT * FROM "Security_Prices_Detail"',
    "inv_pnl_summary"       : 'SELECT * FROM "Inv_Pnl_Summary"',
    "inv_security_position" : 'SELECT * FROM "Inv_Security_Position"',  # ← new
}

# ── Only change this line to switch query ──
SQL_QUERY = QUERIES["perf_benchmark"]

# %%
# Cell 3 — Display function
def display_df(df):
    return df.style.set_properties(**{
        'white-space': 'nowrap',
        'font-size': '11px',
        'text-align': 'left',
        'border': '1px solid lightgrey',
        'color': 'black'
    }).set_table_styles([
        {
            'selector': 'thead th',
            'props': [
                ('white-space', 'nowrap'),
                ('font-size', '11px'),
                ('font-weight', 'bold'),
                ('background-color', '#4472C4'),
                ('color', 'white'),
                ('text-align', 'center'),
                ('border', '1px solid lightgrey')
            ]
        },
        {
            'selector': 'tbody tr:nth-child(even)',
            'props': [('background-color', '#f2f2f2'), ('color', 'black')]
        },
        {
            'selector': 'tbody tr:nth-child(odd)',
            'props': [('background-color', 'white'), ('color', 'black')]
        },
        {
            'selector': 'tbody tr:hover',
            'props': [('background-color', '#d6e4f0'), ('color', 'black')]
        }
    ])

# %%
# Cell 4 — Submit the SQL job
response = requests.post(
    f"{BASE_URL}/api/v3/sql",
    headers=HEADERS,
    json={
        "sql": SQL_QUERY,
        "context": SCHEMA
    },
    verify=True,
    timeout=30
)
response.raise_for_status()
job_id = response.json().get("id")
print(f"Job submitted successfully.")
print(f"Job ID: {job_id}")
# Out:
# Job submitted successfully.
# Job ID: 159ece8c-0c5b-9c40-b46b-32fbcc8e4000

# %%
# Cell 5 — Poll until job completes
url = f"{BASE_URL}/api/v3/job/{job_id}"
for attempt in range(30):
    response = requests.get(url, headers=HEADERS, verify=True)
    response.raise_for_status()
    status = response.json().get("jobState")
    print(f"Attempt {attempt + 1}: {status}")
    if status == "COMPLETED":
        print("Job completed!")
        break
    elif status in ("FAILED", "CANCELED"):
        print(f"Job failed: {response.json().get('errorMessage')}")
        break
    time.sleep(2)
# Out:
# Attempt 1: COMPLETED
# Job completed!

# %%
# Cell 6 — Fetch results and build DataFrame
response = requests.get(
    f"{BASE_URL}/api/v3/job/{job_id}/results?offset=0&limit=500",
    headers=HEADERS,
    verify=True
)
response.raise_for_status()
data = response.json()

columns   = [col["name"] for col in data.get("schema", [])]
all_rows  = data.get("rows", [])
total     = data.get("rowCount", None)

# ── Paginate if more than 500 rows ──
offset = 500
while True:
    r = requests.get(
        f"{BASE_URL}/api/v3/job/{job_id}/results?offset={offset}&limit=500",
        headers=HEADERS,
        verify=True
    )
    batch = r.json().get("rows", [])
    if not batch:
        break
    all_rows.extend(batch)
    offset += len(batch)
    print(f"Fetched {offset} rows so far...")

df = pd.DataFrame(all_rows, columns=columns)
print(f"Total Rows    : {len(df)}")
print(f"Total Columns : {len(df.columns)}")
# Out:
# Total Rows    : 2
# Total Columns : 27

# %%
display_df(df.head(10))   # first 10 rows
# Out:
# <style type="text/css">
# #T_06a41 thead th {
#   white-space: nowrap;
#   font-size: 11px;
#   font-weight: bold;
#   background-color: #4472C4;
#   color: white;
#   text-align: center;
#   border: 1px solid lightgrey;
# }
# #T_06a41 tbody tr:nth-child(even) {
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_06a41 tbody tr:nth-child(odd) {
#   background-color: white;
#   color: black;
# }
# #T_06a41 tbody tr:hover {
#   background-color: #d6e4f0;
#   color: black;
# }
# #T_06a41_row0_col0, #T_06a41_row0_col1, #T_06a41_row0_col2, #T_06a41_row0_col3, #T_06a41_row0_col4, #T_06a41_row0_col5, #T_06a41_row0_col6, #T_06a41_row0_col7, #T_06a41_row0_col8, #T_06a41_row0_col9, #T_06a41_row0_col10, #T_06a41_row0_col11, #T_06a41_row0_col12, #T_06a41_row0_col13, #T_06a41_row0_col14, #T_06a41_row0_col15, #T_06a41_row0_col16, #T_06a41_row0_col17, #T_06a41_row0_col18, #T_06a41_row0_col19, #T_06a41_row0_col20, #T_06a41_row0_col21, #T_06a41_row0_col22, #T_06a41_row0_col23, #T_06a41_row0_col24, #T_06a41_row0_col25, #T_06a41_row0_col26, #T_06a41_row1_col0, #T_06a41_row1_col1, #T_06a41_row1_col2, #T_06a41_row1_col3, #T_06a41_row1_col4, #T_06a41_row1_col5, #T_06a41_row1_col6, #T_06a41_row1_col7, #T_06a41_row1_col8, #T_06a41_row1_col9, #T_06a41_row1_col10, #T_06a41_row1_col11, #T_06a41_row1_col12, #T_06a41_row1_col13, #T_06a41_row1_col14, #T_06a41_row1_col15, #T_06a41_row1_col16, #T_06a41_row1_col17, #T_06a41_row1_col18, #T_06a41_row1_col19, #T_06a41_row1_col20, #T_06a41_row1_col21, #T_06a41_row1_col22, #T_06a41_row1_col23, #T_06a41_row1_col24, #T_06a41_row1_col25, #T_06a41_row1_col26 {
#   white-space: nowrap;
#   font-size: 11px;
#   text-align: left;
#   border: 1px solid lightgrey;
#   color: black;
# }
# </style>
# <table id="T_06a41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06a41_level0_col0" class="col_heading level0 col0" >Business_Date</th>
#       <th id="T_06a41_level0_col1" class="col_heading level0 col1" >MX_REF_DATA</th>
#       <th id="T_06a41_level0_col2" class="col_heading level0 col2" >MX_REF_JOB</th>
#       <th id="T_06a41_level0_col3" class="col_heading level0 col3" >MX_ACCRUED</th>
#       <th id="T_06a41_level0_col4" class="col_heading level0 col4" >Clean_Price</th>
#       <th id="T_06a41_level0_col5" class="col_heading level0 col5" >Closing_date</th>
#       <th id="T_06a41_level0_col6" class="col_heading level0 col6" >CUSIP</th>
#       <th id="T_06a41_level0_col7" class="col_heading level0 col7" >MX_DATA_DATE</th>
#       <th id="T_06a41_level0_col8" class="col_heading level0 col8" >Data_Label</th>
#       <th id="T_06a41_level0_col9" class="col_heading level0 col9" >Data_Generation_Date</th>
#       <th id="T_06a41_level0_col10" class="col_heading level0 col10" >Data_Generation_Desk</th>
#       <th id="T_06a41_level0_col11" class="col_heading level0 col11" >Data_Generation_Group</th>
#       <th id="T_06a41_level0_col12" class="col_heading level0 col12" >Data_Generation_Time</th>
#       <th id="T_06a41_level0_col13" class="col_heading level0 col13" >Data_Generation_User</th>
#       <th id="T_06a41_level0_col14" class="col_heading level0 col14" >ISIN</th>
#       <th id="T_06a41_level0_col15" class="col_heading level0 col15" >Benchmark_Name</th>
#       <th id="T_06a41_level0_col16" class="col_heading level0 col16" >Market_value</th>
#       <th id="T_06a41_level0_col17" class="col_heading level0 col17" >NB_Shares</th>
#       <th id="T_06a41_level0_col18" class="col_heading level0 col18" >MX_NOTATION</th>
#       <th id="T_06a41_level0_col19" class="col_heading level0 col19" >Security_ID</th>
#       <th id="T_06a41_level0_col20" class="col_heading level0 col20" >Weight</th>
#       <th id="T_06a41_level0_col21" class="col_heading level0 col21" >UUID</th>
#       <th id="T_06a41_level0_col22" class="col_heading level0 col22" >FeedName</th>
#       <th id="T_06a41_level0_col23" class="col_heading level0 col23" >ProcessedTimeStamp</th>
#       <th id="T_06a41_level0_col24" class="col_heading level0 col24" >AccountingDate</th>
#       <th id="T_06a41_level0_col25" class="col_heading level0 col25" >BatchID</th>
#       <th id="T_06a41_level0_col26" class="col_heading level0 col26" >LastProcessedBatchId</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06a41_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06a41_row0_col0" class="data row0 col0" >2026-07-17</td>
#       <td id="T_06a41_row0_col1" class="data row0 col1" >Dummy</td>
#       <td id="T_06a41_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_06a41_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_06a41_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_06a41_row0_col5" class="data row0 col5" >2026-07-17</td>
#       <td id="T_06a41_row0_col6" class="data row0 col6" >Dummy</td>
#       <td id="T_06a41_row0_col7" class="data row0 col7" >2026-07-17</td>
#       <td id="T_06a41_row0_col8" class="data row0 col8" >Dummy</td>
#       <td id="T_06a41_row0_col9" class="data row0 col9" >2026-07-17</td>
#       <td id="T_06a41_row0_col10" class="data row0 col10" >Dummy</td>
#       <td id="T_06a41_row0_col11" class="data row0 col11" >Dummy</td>
#       <td id="T_06a41_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_06a41_row0_col13" class="data row0 col13" >Dummy</td>
#       <td id="T_06a41_row0_col14" class="data row0 col14" >Dummy</td>
#       <td id="T_06a41_row0_col15" class="data row0 col15" >Dummy</td>
#       <td id="T_06a41_row0_col16" class="data row0 col16" >0.000000</td>
#       <td id="T_06a41_row0_col17" class="data row0 col17" >0.000000</td>
#       <td id="T_06a41_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_06a41_row0_col19" class="data row0 col19" >Dummy</td>
#       <td id="T_06a41_row0_col20" class="data row0 col20" >0.000000</td>
#       <td id="T_06a41_row0_col21" class="data row0 col21" >d17832a6-0754-473a-98a8-1aad97e2bfa5-20260718024724</td>
#       <td id="T_06a41_row0_col22" class="data row0 col22" >FINVPRFBNCHSE</td>
#       <td id="T_06a41_row0_col23" class="data row0 col23" >2026-07-18 02:46:25.000</td>
#       <td id="T_06a41_row0_col24" class="data row0 col24" >2026-07-19</td>
#       <td id="T_06a41_row0_col25" class="data row0 col25" >202607170001</td>
#       <td id="T_06a41_row0_col26" class="data row0 col26" >202607170001</td>
#     </tr>
#     <tr>
#       <th id="T_06a41_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_06a41_row1_col0" class="data row1 col0" >2026-07-21</td>
#       <td id="T_06a41_row1_col1" class="data row1 col1" >Dummy</td>
#       <td id="T_06a41_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_06a41_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_06a41_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_06a41_row1_col5" class="data row1 col5" >2026-07-21</td>
#       <td id="T_06a41_row1_col6" class="data row1 col6" >Dummy</td>
#       <td id="T_06a41_row1_col7" class="data row1 col7" >2026-07-21</td>
#       <td id="T_06a41_row1_col8" class="data row1 col8" >Dummy</td>
#       <td id="T_06a41_row1_col9" class="data row1 col9" >2026-07-21</td>
#       <td id="T_06a41_row1_col10" class="data row1 col10" >Dummy</td>
#       <td id="T_06a41_row1_col11" class="data row1 col11" >Dummy</td>
#       <td id="T_06a41_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_06a41_row1_col13" class="data row1 col13" >Dummy</td>
#       <td id="T_06a41_row1_col14" class="data row1 col14" >Dummy</td>
#       <td id="T_06a41_row1_col15" class="data row1 col15" >Dummy</td>
#       <td id="T_06a41_row1_col16" class="data row1 col16" >0.000000</td>
#       <td id="T_06a41_row1_col17" class="data row1 col17" >0.000000</td>
#       <td id="T_06a41_row1_col18" class="data row1 col18" >0</td>
#       <td id="T_06a41_row1_col19" class="data row1 col19" >Dummy</td>
#       <td id="T_06a41_row1_col20" class="data row1 col20" >0.000000</td>
#       <td id="T_06a41_row1_col21" class="data row1 col21" >de47a400-a587-49d9-a97d-462836b7153b-20260722024805</td>
#       <td id="T_06a41_row1_col22" class="data row1 col22" >FINVPRFBNCHSE</td>
#       <td id=

# %%
display_df(df.tail(10))   # last 10 rows
# Out:
# <style type="text/css">
# #T_cf5fe thead th {
#   white-space: nowrap;
#   font-size: 11px;
#   font-weight: bold;
#   background-color: #4472C4;
#   color: white;
#   text-align: center;
#   border: 1px solid lightgrey;
# }
# #T_cf5fe tbody tr:nth-child(even) {
#   background-color: #f2f2f2;
#   color: black;
# }
# #T_cf5fe tbody tr:nth-child(odd) {
#   background-color: white;
#   color: black;
# }
# #T_cf5fe tbody tr:hover {
#   background-color: #d6e4f0;
#   color: black;
# }
# #T_cf5fe_row0_col0, #T_cf5fe_row0_col1, #T_cf5fe_row0_col2, #T_cf5fe_row0_col3, #T_cf5fe_row0_col4, #T_cf5fe_row0_col5, #T_cf5fe_row0_col6, #T_cf5fe_row0_col7, #T_cf5fe_row0_col8, #T_cf5fe_row0_col9, #T_cf5fe_row0_col10, #T_cf5fe_row0_col11, #T_cf5fe_row0_col12, #T_cf5fe_row0_col13, #T_cf5fe_row0_col14, #T_cf5fe_row0_col15, #T_cf5fe_row0_col16, #T_cf5fe_row0_col17, #T_cf5fe_row0_col18, #T_cf5fe_row0_col19, #T_cf5fe_row0_col20, #T_cf5fe_row0_col21, #T_cf5fe_row0_col22, #T_cf5fe_row0_col23, #T_cf5fe_row0_col24, #T_cf5fe_row0_col25, #T_cf5fe_row0_col26, #T_cf5fe_row0_col27, #T_cf5fe_row0_col28, #T_cf5fe_row0_col29, #T_cf5fe_row0_col30, #T_cf5fe_row0_col31, #T_cf5fe_row0_col32, #T_cf5fe_row0_col33, #T_cf5fe_row0_col34, #T_cf5fe_row0_col35, #T_cf5fe_row0_col36, #T_cf5fe_row0_col37, #T_cf5fe_row0_col38, #T_cf5fe_row0_col39, #T_cf5fe_row0_col40, #T_cf5fe_row0_col41, #T_cf5fe_row0_col42, #T_cf5fe_row0_col43, #T_cf5fe_row0_col44, #T_cf5fe_row0_col45, #T_cf5fe_row0_col46, #T_cf5fe_row0_col47, #T_cf5fe_row0_col48, #T_cf5fe_row0_col49, #T_cf5fe_row0_col50, #T_cf5fe_row0_col51, #T_cf5fe_row0_col52, #T_cf5fe_row0_col53, #T_cf5fe_row0_col54, #T_cf5fe_row0_col55, #T_cf5fe_row0_col56, #T_cf5fe_row0_col57, #T_cf5fe_row0_col58, #T_cf5fe_row0_col59, #T_cf5fe_row0_col60, #T_cf5fe_row0_col61, #T_cf5fe_row0_col62, #T_cf5fe_row0_col63, #T_cf5fe_row0_col64, #T_cf5fe_row0_col65, #T_cf5fe_row0_col66, #T_cf5fe_row0_col67, #T_cf5fe_row0_col68, #T_cf5fe_row0_col69, #T_cf5fe_row0_col70, #T_cf5fe_row0_col71, #T_cf5fe_row0_col72, #T_cf5fe_row0_col73, #T_cf5fe_row0_col74, #T_cf5fe_row0_col75, #T_cf5fe_row0_col76, #T_cf5fe_row0_col77, #T_cf5fe_row0_col78, #T_cf5fe_row0_col79, #T_cf5fe_row0_col80, #T_cf5fe_row0_col81, #T_cf5fe_row0_col82, #T_cf5fe_row0_col83, #T_cf5fe_row0_col84, #T_cf5fe_row0_col85, #T_cf5fe_row0_col86, #T_cf5fe_row0_col87, #T_cf5fe_row0_col88, #T_cf5fe_row0_col89, #T_cf5fe_row0_col90, #T_cf5fe_row0_col91, #T_cf5fe_row0_col92, #T_cf5fe_row0_col93, #T_cf5fe_row0_col94, #T_cf5fe_row0_col95, #T_cf5fe_row1_col0, #T_cf5fe_row1_col1, #T_cf5fe_row1_col2, #T_cf5fe_row1_col3, #T_cf5fe_row1_col4, #T_cf5fe_row1_col5, #T_cf5fe_row1_col6, #T_cf5fe_row1_col7, #T_cf5fe_row1_col8, #T_cf5fe_row1_col9, #T_cf5fe_row1_col10, #T_cf5fe_row1_col11, #T_cf5fe_row1_col12, #T_cf5fe_row1_col13, #T_cf5fe_row1_col14, #T_cf5fe_row1_col15, #T_cf5fe_row1_col16, #T_cf5fe_row1_col17, #T_cf5fe_row1_col18, #T_cf5fe_row1_col19, #T_cf5fe_row1_col20, #T_cf5fe_row1_col21, #T_cf5fe_row1_col22, #T_cf5fe_row1_col23, #T_cf5fe_row1_col24, #T_cf5fe_row1_col25, #T_cf5fe_row1_col26, #T_cf5fe_row1_col27, #T_cf5fe_row1_col28, #T_cf5fe_row1_col29, #T_cf5fe_row1_col30, #T_cf5fe_row1_col31, #T_cf5fe_row1_col32, #T_cf5fe_row1_col33, #T_cf5fe_row1_col34, #T_cf5fe_row1_col35, #T_cf5fe_row1_col36, #T_cf5fe_row1_col37, #T_cf5fe_row1_col38, #T_cf5fe_row1_col39, #T_cf5fe_row1_col40, #T_cf5fe_row1_col41, #T_cf5fe_row1_col42, #T_cf5fe_row1_col43, #T_cf5fe_row1_col44, #T_cf5fe_row1_col45, #T_cf5fe_row1_col46, #T_cf5fe_row1_col47, #T_cf5fe_row1_col48, #T_cf5fe_row1_col49, #T_cf5fe_row1_col50, #T_cf5fe_row1_col51, #T_cf5fe_row1_col52, #T_cf5fe_row1_col53, #T_cf5fe_row1_col54, #T_cf5fe_row1_col55, #T_cf5fe_row1_col56, #T_cf5fe_row1_col57, #T_cf5fe_row1_col58, #T_cf5fe_row1_col59, #T_cf5fe_row1_col60, #T_cf5fe_row1_col61, #T_cf5fe_row1_col62, #T_cf5fe_row1_col63, #T_cf5fe_row1_col64, #T_cf5fe_row1_col65, #T_cf5fe_row1_col66, #T_cf5fe_row1_col67, #T_cf5fe_row1_col68, #T_cf5fe_row1_col69, #T_cf5fe_row1_col70, #T_cf5fe_row1_col71, #T_cf5fe_row1_col72, #T_cf5fe_row1_col73, #T_cf5fe_row1_col74, #T_cf5fe_row1_col75, #T_cf5fe_row1_col76, #T_cf5fe_row1_col77, #T_cf5fe_row1_col78, #T_cf5fe_row1_col79, #T_cf5fe_row1_col80, #T_cf5fe_row1_col81, #T_cf5fe_row1_col82, #T_cf5fe_row1_col83, #T_cf5fe_row1_col84, #T_cf5fe_row1_col85, #T_cf5fe_row1_col86, #T_cf5fe_row1_col87, #T_cf5fe_row1_col88, #T_cf5fe_row1_col89, #T_cf5fe_row1_col90, #T_cf5fe_row1_col91, #T_cf5fe_row1_col92, #T_cf5fe_row1_col93, #T_cf5fe_row1_col94, #T_cf5fe_ ...

# %%
# Cell 7 — Display the DataFrame
#display_df(df.head(10))   # first 10 rows
#display_df(df.tail(10))   # last 10 rows
display_df(df)            # everything

# %%
df.tail()

# %%
# Cell 8 — Optional: Save to CSV or Excel
df.to_csv("output.csv", index=False)
print("Saved to output.csv")

df.to_excel("output.xlsx", index=False)
print("Saved to output.xlsx")
